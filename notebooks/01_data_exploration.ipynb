# %% [markdown]
# # 01 Data Exploration
# Inspect raw data quality, missingness, class balance, and feature distributions.

# %%
import pandas as pd
from pathlib import Path

data_path = Path('../data/raw/spotify.csv')
df = pd.read_csv(data_path)
df.head()
# Out:
#    HIT                   SONG                           ARTIST  PEAK_POSITION  \
# 0    0  0 to 100 the catch up                            drake             35
# 1    1        03 bonnie clyde  jay z featuring beyonce knowles              4
# 2    0                      1                            nelly             22
# 3    0           1 000 laughs                      eloise laws             91
# 4    0                    1 1                          beyonce             57
#
#   FIRST_WEEK  WEEKS_ON_CHART             SONG_DISPLAY  \
# 0     8/9/14              20  0 To 100 / The Catch Up
# 1   10/26/02              23       '03 Bonnie & Clyde
# 2   10/20/01              20                       #1
# 3    1/14/78               6             1,000 Laughs
# 4    6/11/11               2                      1+1
#
#                     ARTIST_DISPLAY  DEBUT_RANK  DANCEABILITY  ...  \
# 0                            Drake          63         0.707  ...
# ...
